# %%
from change_detection import ChangeDetection

# %% [markdown]
# ### Change detection result using symmetrized KL CP score

# %%
cpd = ChangeDetection(tau=5, score_method='symmetrized kl')
cpd.run()

# %% [markdown]
# ### Change detection result using log likelihood CP score

# %%
cpd = ChangeDetection(tau=5)
cpd.run()
